# %%
import zipfile
import os
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import ipywidgets as widgets
import pandas as pd
import io

from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing import image
from tensorflow.keras import layers, models
from PIL import Image
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models, Sequential
from tensorflow.keras.layers import InputLayer, Flatten, Dense

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Path direktori hasil ekstraksi
data_dir = '/content/drive/MyDrive/CAPSTONE_PROYEK/DatasetMinumanCapstone'

# Tampilkan daftar folder di direktori dataset
print("Files in directory:", os.listdir(data_dir))

# Hitung jumlah kategori (subfolder)
print("Number of categories (folders):", len(os.listdir(data_dir)))

#jumlah produk diambil dari total folder
num_classes = len(os.listdir(data_dir))

#Penyesuaian ukuran gambar
image_size = 120
# Out:
# Files in directory: ['ABC Kopi Susu', 'BearBrand', 'Benecol rasa lyche botol 100 ml', 'Cimory bebas laktosa 250ml', 'Cimory Susu Coklat rasa cashew 250 ml', 'Cimory Yogurt Strawberry 250ml', 'Cola-Cola 390ml', 'Floridina', 'Fruit Tea Freeze 350ml', 'Hydro Coco Original 250 ml', 'Ichitan Thai Green Tea', 'Larutan Penyegar Rasa Jambu', 'Mizone 500ml', 'NU Green Tea Yogurt', 'Nutriboost Orange Flavour 250ml', 'pepsi blue 330 ml', 'Pocari Sweat 500 ml', 'Sprite 390ml', 'TEBS Sparkling 330ml', 'Teh kotak 200 ml', 'Teh Pucuk Harum', 'Tehbotol sosro 250ml', 'Ultra milk coklat Ultrajaya 200ml', 'Ultramilk Fullcream 250ml', 'Yakult', 'You c 1000 orange']
# Number of categories (folders): 26

# %%
#Fungsi untuk augmentasi model
def create_augmentation_model():
    """Creates a model (layers stacked on top of each other) for augmenting images.

    Returns:
        tf.keras.Model: The model made up of the layers that will be used to augment the images.
    """
    augmentation_model = tf.keras.Sequential([
        tf.keras.layers.RandomRotation(0.2),  # Rotasi acak
        tf.keras.layers.RandomZoom(0.2),     # Zoom acak
        tf.keras.layers.RandomFlip("horizontal"),  # Flip horizontal
        tf.keras.layers.RandomTranslation(0.2, 0.2)  # Translasi acak pada X dan Y
    ])
    return augmentation_model

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras import Sequential

#Fungsi untuk membuat model
def create_classification_model(image_size, num_classes):
    model = Sequential([
        Conv2D(16, (3, 3), activation='relu', input_shape=(image_size, image_size, 3)),
        MaxPooling2D((2, 2)),

        Conv2D(32, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),

        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),

        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),

        Flatten(),
        Dense(256, activation='relu'),
        Dropout(0.5),
        Dense(128, activation='relu'),
        Dropout(0.5),

        Dense(num_classes, activation='softmax')
    ])

    return model

# %%
def preprocess_image(file_path, image_size):
    """
    Fungsi untuk memproses gambar: memuat gambar, mengubah ukurannya, dan menormalkan.
    Args:
        file_path (str): Path file gambar
    Returns:
        tf.Tensor: Gambar yang sudah diproses
    """
    # Membaca gambar
    image = tf.io.read_file(file_path)
    image = tf.image.decode_jpeg(image, channels=3)  # Mengkodekan gambar dalam format RGB

    # Mengubah ukuran gambar sesuai ukuran gambar yang ditentukan di image_size
    image = tf.image.resize(image, [image_size, image_size])

    # Normalisasi gambar (opsional, bisa disesuaikan)
    image = image / 255.0  # Mengubah nilai pixel menjadi antara 0 dan 1

    return image

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

def create_data_generators(data_dir, image_size):
    """Creates ImageDataGenerators for training and validation with augmentation for a simple CNN."""
    train_datagen = ImageDataGenerator(
        rescale=1./255,  # Normalisasi sederhana
        rotation_range=20,
        zoom_range=0.2,
        horizontal_flip=True,
        width_shift_range=0.2,
        height_shift_range=0.2,
        validation_split=0.2  # Membagi data menjadi pelatihan dan validasi dengan perbandingan 1/5
    )

    # Generator untuk set pelatihan
    train_generator = train_datagen.flow_from_directory(
        data_dir,
        target_size=(image_size, image_size),
        batch_size=32,
        class_mode='categorical',
        subset='training'  # Menggunakan subset training
    )

    # Generator untuk set validasi (tanpa augmentasi tambahan)
    val_generator = train_datagen.flow_from_directory(
        data_dir,
        target_size=(image_size, image_size),
        batch_size=32,
        class_mode='categorical',
        subset='validation'  # Menggunakan subset validation
    )

    return train_generator, val_generator

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

def train_model(model, train_generator, val_generator, epochs=100, patience=5, save_path='best_model.keras'): # Changed the file extension to .keras
    """
    Melatih model menggunakan data pelatihan dan validasi dengan callbacks untuk early stopping dan model checkpoint.

    Parameters:
    - model: Model yang akan dilatih.
    - train_generator: Generator untuk data pelatihan.
    - val_generator: Generator untuk data validasi.
    - epochs: Jumlah maksimum epoch untuk pelatihan.
    - patience: Jumlah epoch tanpa perbaikan sebelum menghentikan pelatihan (early stopping).
    - save_path: Path untuk menyimpan model terbaik berdasarkan performa pada set validasi.

    Returns:
    - history: Riwayat pelatihan model.
    """
    # Compile model
    Optimizer = Adam(learning_rate=1e-3)
    model.compile(optimizer=Optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

    # Callback untuk menghentikan pelatihan lebih awal jika tidak ada perbaikan pada set validasi
    early_stopping = EarlyStopping(monitor='val_loss', patience=patience, restore_best_weights=True)

    # Callback untuk menyimpan model terbaik selama pelatihan
    model_checkpoint = ModelCheckpoint(save_path, monitor='val_loss', save_best_only=True)

    # Melatih model
    history = model.fit(
        train_generator,
        validation_data=val_generator,
        epochs=epochs,
        callbacks=[early_stopping, model_checkpoint]
    )

    return history

# %%
# Membuat model augmentasi
augmentation_model = create_augmentation_model()

# Membuat model klasifikasi dengan transfer learning
classification_model = create_classification_model(image_size, num_classes)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
path = "/content/drive/MyDrive/CAPSTONE_PROYEK/DatasetMinumanCapstone/Ichitan Thai Green Tea/ICHI1 (1).jpg"
print(os.path.exists(path))
dataset = tf.data.Dataset.list_files(path)


dataset = dataset.map(lambda x: preprocess_image(x, image_size))  # Fungsi untuk memproses gambar
dataset = dataset.batch(32)  # Mengambil batch berisi 32 gambar

# Ambil batch pertama
example_batch_images = next(iter(dataset))
sample_image = tf.keras.utils.array_to_img(example_batch_images[0])

# Terapkan augmentasi acak 3 kali
images = [sample_image]

for _ in range(3):
    # Tambahkan dimensi batch (misalnya, batch size 1)
    image_with_batch = tf.expand_dims(sample_image, axis=0)

    # Augmentasi gambar
    image_aug = augmentation_model(image_with_batch)
    image_aug = tf.image.resize(image_aug, [image_size, image_size])  # Resize augmented images
    image_aug = tf.keras.utils.array_to_img(tf.squeeze(image_aug))
    images.append(image_aug)


# Menampilkan gambar
fig, axs = plt.subplots(1, 4, figsize=(14, 7))
for ax, image, title in zip(axs, images, ['Original Image', 'Augmented 1', 'Augmented 2', 'Augmented 3']):
    ax.imshow(image)
    ax.set_title(title)
    ax.axis('off')

plt.show()
# Out:
# True

# %%
#melakukan training model
train_generator, val_generator = create_data_generators(data_dir, image_size)
history = train_model(classification_model, train_generator, val_generator, epochs=100, patience=20, save_path='best_model.keras')
# Out:
# Found 1026 images belonging to 26 classes.
# Found 253 images belonging to 26 classes.
# Epoch 1/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 38s 840ms/step - accuracy: 0.0466 - loss: 3.2634 - val_accuracy: 0.1107 - val_loss: 3.1561
# Epoch 2/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 32s 828ms/step - accuracy: 0.0856 - loss: 3.1522 - val_accuracy: 0.1067 - val_loss: 2.9580
# Epoch 3/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 39s 765ms/step - accuracy: 0.0926 - loss: 3.0496 - val_accuracy: 0.1383 - val_loss: 2.8804
# Epoch 4/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 35s 934ms/step - accuracy: 0.1034 - loss: 2.9288 - val_accuracy: 0.1660 - val_loss: 2.7985
# Epoch 5/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 30s 769ms/step - accuracy: 0.1044 - loss: 2.8812 - val_accuracy: 0.1383 - val_loss: 2.7177
# Epoch 6/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 31s 793ms/step - accuracy: 0.1050 - loss: 2.8569 - val_accuracy: 0.1976 - val_loss: 2.6634
# Epoch 7/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 35s 874ms/step - accuracy: 0.1159 - loss: 2.8052 - val_accuracy: 0.2648 - val_loss: 2.5464
# Epoch 8/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 30s 774ms/step - accuracy: 0.1940 - loss: 2.6931 - val_accuracy: 0.2806 - val_loss: 2.3502
# Epoch 9/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 40s 775ms/step - accuracy: 0.2200 - loss: 2.5928 - val_accuracy: 0.3123 - val_loss: 2.3574
# Epoch 10/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 42s 822ms/step - accuracy: 0.2479 - loss: 2.4387 - val_accuracy: 0.3360 - val_loss: 2.2026
# Epoch 11/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 35s 889ms/step - accuracy: 0.2701 - loss: 2.3629 - val_accuracy: 0.3597 - val_loss: 2.0417
# Epoch 12/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 37s 777ms/step - accuracy: 0.2985 - loss: 2.2619 - val_accuracy: 0.4111 - val_loss: 1.8876
# Epoch 13/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 46s 909ms/step - accuracy: 0.3412 - loss: 2.2215 - val_accuracy: 0.4269 - val_loss: 1.8478
# Epoch 14/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 32s 789ms/step - accuracy: 0.3543 - loss: 2.0168 - val_accuracy: 0.4862 - val_loss: 1.6988
# Epoch 15/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 30s 708ms/step - accuracy: 0.3763 - loss: 2.0531 - val_accuracy: 0.5059 - val_loss: 1.6517
# Epoch 16/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 42s 774ms/step - accuracy: 0.3280 - loss: 2.1538 - val_accuracy: 0.4704 - val_loss: 1.6447
# Epoch 17/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 29s 733ms/step - accuracy: 0.4103 - loss: 1.9035 - val_accuracy: 0.5099 - val_loss: 1.5984
# Epoch 18/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 30s 772ms/step - accuracy: 0.4252 - loss: 1.7968 - val_accuracy: 0.5889 - val_loss: 1.4454
# Epoch 19/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 29s 741ms/step - accuracy: 0.4450 - loss: 1.7836 - val_accuracy: 0.4941 - val_loss: 1.4939
# Epoch 20/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 30s 790ms/step - accuracy: 0.4539 - loss: 1.6550 - val_accuracy: 0.5850 - val_loss: 1.4665
# Epoch 21/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 39s 712ms/step - accuracy: 0.4771 - loss: 1.6927 - val_accuracy: 0.5771 - val_loss: 1.3231
# Epoch 22/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 31s 760ms/step - accuracy: 0.5035 - loss: 1.6457 - val_accuracy: 0.6482 - val_loss: 1.2821
# Epoch 23/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 39s 732ms/step - accuracy: 0.5322 - loss: 1.4185 - val_accuracy: 0.6364 - val_loss: 1.1789
# Epoch 24/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 30s 739ms/step - accuracy: 0.5527 - loss: 1.4818 - val_accuracy: 0.6364 - val_loss: 1.1358
# Epoch 25/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 41s 727ms/step - accuracy: 0.5603 - loss: 1.4386 - val_accuracy: 0.6206 - val_loss: 1.3467
# Epoch 26/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 31s 774ms/step - accuracy: 0.5741 - loss: 1.3614 - val_accuracy: 0.6245 - val_loss: 1.2239
# Epoch 27/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 30s 760ms/step - accuracy: 0.5794 - loss: 1.3476 - val_accuracy: 0.6640 - val_loss: 1.0833
# Epoch 28/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 42s 799ms/step - accuracy: 0.6122 - loss: 1.2405 - val_accuracy: 0.6877 - val_loss: 0.9769
# Epoch 29/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 30s 761ms/step - accuracy: 0.6208 - loss: 1.2487 - val_accuracy: 0.6917 - val_loss: 1.0971
# Epoch 30/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 42s 766ms/step - accuracy: 0.6026 - loss: 1.2901 - val_accuracy: 0.6798 - val_loss: 1.0810
# Epoch 31/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 40s 728ms/step - accuracy: 0.6307 - loss: 1.1759 - val_accuracy: 0.7194 - val_loss: 0.9289
# Epoch 32/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 32s 819ms/step - accuracy: 0.6520 - loss: 1.1467 - val_accuracy: 0.7194 - val_loss: 1.0830
# Epoch 33/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 43s 853ms/step - accuracy: 0.6861 - loss: 1.0969 - val_accuracy: 0.7352 - val_loss: 0.9245
# Epoch 34/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 30s 779ms/step - accuracy: 0.7108 - loss: 0.9366 - val_accuracy: 0.7470 - val_loss: 0.9296
# Epoch 35/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 29s 764ms/step - accuracy: 0.6550 - loss: 1.0704 - val_accuracy: 0.7273 - val_loss: 0.9196
# Epoch 36/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 31s 743ms/step - accuracy: 0.6973 - loss: 0.8891 - val_accuracy: 0.7312 - val_loss: 0.8951
# Epoch 37/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 30s 729ms/step - accuracy: 0.6759 - loss: 1.0891 - val_accuracy: 0.7115 - val_loss: 0.8763
# Epoch 38/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 43s 797ms/step - accuracy: 0.7034 - loss: 0.9684 - val_accuracy: 0.7668 - val_loss: 0.8362
# Epoch 39/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 43s 878ms/step - accuracy: 0.7570 - loss: 0.7994 - val_accuracy: 0.7589 - val_loss: 0.8642
# Epoch 40/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 39s 780ms/step - accuracy: 0.7440 - loss: 0.7865 - val_accuracy: 0.7905 - val_loss: 0.8139
# Epoch 41/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 28s 716ms/step - accuracy: 0.7661 - loss: 0.7562 - val_accuracy: 0.7747 - val_loss: 0.8131
# Epoch 42/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 30s 795ms/step - accuracy: 0.7312 - loss: 0.8876 - val_accuracy: 0.7470 - val_loss: 0.8403
# Epoch 43/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 29s 774ms/step - accuracy: 0.7174 - loss: 0.9726 - val_accuracy: 0.7747 - val_loss: 0.7807
# Epoch 44/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 35s 861ms/step - accuracy: 0.7712 - loss: 0.7721 - val_accuracy: 0.8103 - val_loss: 0.6278
# Epoch 45/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 35s 683ms/step - accuracy: 0.7946 - loss: 0.6965 - val_accuracy: 0.8103 - val_loss: 0.6733
# Epoch 46/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 35s 923ms/step - accuracy: 0.8045 - loss: 0.6459 - val_accuracy: 0.7747 - val_loss: 0.7450
# Epoch 47/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 29s 751ms/step - accuracy: 0.8106 - loss: 0.6032 - val_accuracy: 0.7826 - val_loss: 0.7051
# Epoch 48/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 30s 785ms/step - accuracy: 0.8047 - loss: 0.6867 - val_accuracy: 0.8142 - val_loss: 0.6398
# Epoch 49/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 28s 679ms/step - accuracy: 0.8141 - loss: 0.6197 - val_accuracy: 0.8577 - val_loss: 0.5906
# Epoch 50/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 35s 887ms/step - accuracy: 0.8214 - loss: 0.6181 - val_accuracy: 0.8498 - val_loss: 0.6397
# Epoch 51/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 34s 685ms/step - accuracy: 0.7955 - loss: 0.6586 - val_accuracy: 0.8103 - val_loss: 0.6604
# Epoch 52/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 34s 871ms/step - accuracy: 0.8237 - loss: 0.5695 - val_accuracy: 0.8419 - val_loss: 0.6236
# Epoch 53/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 41s 896ms/step - accuracy: 0.8508 - loss: 0.5347 - val_accuracy: 0.8854 - val_loss: 0.5903
# Epoch 54/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 38s 788ms/step - accuracy: 0.8048 - loss: 0.6587 - val_accuracy: 0.8656 - val_loss: 0.5425
# Epoch 55/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 29s 726ms/step - accuracy: 0.8287 - loss: 0.5654 - val_accuracy: 0.8775 - val_loss: 0.4949
# Epoch 56/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 42s 737ms/step - accuracy: 0.8242 - loss: 0.5202 - val_accuracy: 0.8538 - val_loss: 0.5258
# Epoch 57/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 40s 722ms/step - accuracy: 0.8528 - loss: 0.5080 - val_accuracy: 0.8419 - val_loss: 0.4887
# Epoch 58/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 42s 780ms/step - accuracy: 0.8336 - loss: 0.5165 - val_accuracy: 0.8696 - val_loss: 0.5811
# Epoch 59/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 40s 724ms/step - accuracy: 0.8486 - loss: 0.4694 - val_accuracy: 0.9051 - val_loss: 0.5337
# Epoch 60/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 30s 705ms/step - accuracy: 0.8442 - loss: 0.5404 - val_accuracy: 0.8972 - val_loss: 0.4822
# Epoch 61/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 40s 705ms/step - accuracy: 0.8438 - loss: 0.5455 - val_accuracy: 0.8735 - val_loss: 0.5343
# Epoch 62/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 47s 880ms/step - accuracy: 0.8406 - loss: 0.5228 - val_accuracy: 0.8854 - val_loss: 0.5233
# Epoch 63/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 29s 772ms/step - accuracy: 0.8369 - loss: 0.5286 - val_accuracy: 0.8656 - val_loss: 0.4851
# Epoch 64/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 30s 797ms/step - accuracy: 0.8844 - loss: 0.4102 - val_accuracy: 0.8617 - val_loss: 0.6765
# Epoch 65/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 39s 740ms/step - accuracy: 0.8697 - loss: 0.4046 - val_accuracy: 0.8498 - val_loss: 0.5609
# Epoch 66/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 35s 890ms/step - accuracy: 0.8696 - loss: 0.4132 - val_accuracy: 0.8696 - val_loss: 0.4428
# Epoch 67/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 28s 743ms/step - accuracy: 0.8924 - loss: 0.3326 - val_accuracy: 0.8735 - val_loss: 0.5369
# Epoch 68/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 31s 818ms/step - accuracy: 0.8726 - loss: 0.3872 - val_accuracy: 0.8458 - val_loss: 0.6158
# Epoch 69/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 44s 937ms/step - accuracy: 0.8878 - loss: 0.4148 - val_accuracy: 0.8538 - val_loss: 0.5936
# Epoch 70/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 30s 807ms/step - accuracy: 0.8882 - loss: 0.3921 - val_accuracy: 0.8854 - val_loss: 0.4968
# Epoch 71/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 29s 771ms/step - accuracy: 0.8903 - loss: 0.4153 - val_accuracy: 0.8300 - val_loss: 0.5503
# Epoch 72/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 42s 809ms/step - accuracy: 0.8845 - loss: 0.4194 - val_accuracy: 0.8893 - val_loss: 0.4617
# Epoch 73/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 30s 790ms/step - accuracy: 0.9084 - loss: 0.3158 - val_accuracy: 0.8656 - val_loss: 0.4565
# Epoch 74/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 42s 794ms/step - accuracy: 0.8977 - loss: 0.3528 - val_accuracy: 0.8893 - val_loss: 0.4489
# Epoch 75/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 33s 839ms/step - accuracy: 0.9092 - loss: 0.2918 - val_accuracy: 0.8893 - val_loss: 0.4447
# Epoch 76/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 30s 800ms/step - accuracy: 0.9073 - loss: 0.2885 - val_accuracy: 0.8735 - val_loss: 0.5277
# Epoch 77/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 40s 765ms/step - accuracy: 0.9178 - loss: 0.3032 - val_accuracy: 0.8735 - val_loss: 0.5540
# Epoch 78/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 41s 744ms/step - accuracy: 0.9151 - loss: 0.3121 - val_accuracy: 0.9051 - val_loss: 0.4641
# Epoch 79/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 28s 691ms/step - accuracy: 0.9134 - loss: 0.2632 - val_accuracy: 0.8775 - val_loss: 0.6065
# Epoch 80/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 44s 758ms/step - accuracy: 0.9021 - loss: 0.3454 - val_accuracy: 0.9130 - val_loss: 0.4120
# Epoch 81/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 29s 766ms/step - accuracy: 0.9221 - loss: 0.2738 - val_accuracy: 0.9091 - val_loss: 0.6175
# Epoch 82/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 30s 783ms/step - accuracy: 0.9203 - loss: 0.2632 - val_accuracy: 0.9012 - val_loss: 0.3523
# Epoch 83/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 40s 761ms/step - accuracy: 0.9227 - loss: 0.2501 - val_accuracy: 0.9209 - val_loss: 0.4912
# Epoch 84/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 42s 808ms/step - accuracy: 0.9168 - loss: 0.3507 - val_accuracy: 0.8419 - val_loss: 0.5055
# Epoch 85/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 40s 780ms/step - accuracy: 0.9026 - loss: 0.3056 - val_accuracy: 0.8814 - val_loss: 0.5052
# Epoch 86/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 42s 765ms/step - accuracy: 0.9269 - loss: 0.2643 - val_accuracy: 0.8893 - val_loss: 0.5258
# Epoch 87/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 29s 686ms/step - accuracy: 0.8948 - loss: 0.3492 - val_accuracy: 0.9091 - val_loss: 0.4365
# Epoch 88/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 43s 747ms/step - accuracy: 0.9317 - loss: 0.2347 - val_accuracy: 0.8854 - val_loss: 0.4988
# Epoch 89/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 40s 758ms/step - accuracy: 0.9122 - loss: 0.2870 - val_accuracy: 0.8933 - val_loss: 0.6708
# Epoch 90/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 43s 814ms/step - accuracy: 0.9050 - loss: 0.2937 - val_accuracy: 0.9012 - val_loss: 0.4174
# Epoch 91/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 30s 775ms/step - accuracy: 0.9371 - loss: 0.2337 - val_accuracy: 0.9209 - val_loss: 0.3657
# Epoch 92/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 31s 794ms/step - accuracy: 0.9430 - loss: 0.1945 - val_accuracy: 0.9368 - val_loss: 0.3466
# Epoch 93/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 39s 749ms/step - accuracy: 0.9384 - loss: 0.2156 - val_accuracy: 0.8972 - val_loss: 0.4223
# Epoch 94/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 36s 928ms/step - accuracy: 0.9512 - loss: 0.1606 - val_accuracy: 0.8854 - val_loss: 0.4748
# Epoch 95/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 31s 802ms/step - accuracy: 0.9448 - loss: 0.2182 - val_accuracy: 0.8933 - val_loss: 0.5058
# Epoch 96/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 40s 807ms/step - accuracy: 0.9195 - loss: 0.2309 - val_accuracy: 0.9012 - val_loss: 0.3863
# Epoch 97/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 39s 750ms/step - accuracy: 0.9417 - loss: 0.2157 - val_accuracy: 0.8933 - val_loss: 0.4242
# Epoch 98/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 43s 796ms/step - accuracy: 0.9206 - loss: 0.2519 - val_accuracy: 0.8893 - val_loss: 0.4117
# Epoch 99/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 34s 841ms/step - accuracy: 0.9414 - loss: 0.2166 - val_accuracy: 0.8933 - val_loss: 0.4996
# Epoch 100/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 39s 785ms/step - accuracy: 0.9383 - loss: 0.2400 - val_accuracy: 0.9051 - val_loss: 0.3909

# %%
import matplotlib.pyplot as plt

# Plot Training and Validation Loss
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')

# Plot Training and Validation Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')

plt.show()

# %%
from io import BytesIO
from IPython.display import display, HTML


# Pastikan model Anda sudah diload sebelumnya
model = classification_model  # Menggunakan model klasifikasi yang dibuat sebelumnya

# Widget untuk meng-upload gambar
uploader = widgets.FileUpload(accept="image/*", multiple=True)
display(uploader)

out = widgets.Output()
display(out)

# Load file CSV
df_nutrition = pd.read_csv('/content/drive/MyDrive/CAPSTONE_PROYEK/MINUMAN.csv')

def preprocess_and_augment(file):
    """
    Fungsi untuk memuat, memproses, dan augmentasi gambar.
    Args:
        file (str): Nama file gambar
    Returns:
        np.array: Gambar yang telah diproses dan diaugmentasi
    """
    # Memuat dan mengubah ukuran gambar
    img = tf.keras.utils.load_img(file, target_size=(image_size, image_size))
    img_array = tf.keras.utils.img_to_array(img) / 255.0  # Normalisasi nilai antara 0 dan 1

    # Augmentasi gambar menggunakan augmentation_model
    img_array = tf.expand_dims(img_array, axis=0)  # Menambahkan dimensi batch
    augmented_img = augmentation_model(img_array)
    return tf.squeeze(augmented_img).numpy()  # Menghapus dimensi batch yang tidak diperlukan

def file_predict(filename, file, out):
    """ Fungsi untuk membuat prediksi, mencetak hasil output, dan menampilkan gambar yang di-upload """
    # Memuat dan mengubah ukuran gambar asli tanpa augmentasi untuk ditampilkan
    original_img = tf.keras.utils.load_img(file, target_size=(image_size, image_size))
    original_img_array = tf.keras.utils.img_to_array(original_img) / 255.0  # Normalisasi nilai antara 0 dan 1

    # Proses dan augmentasi gambar untuk prediksi
    img_array = preprocess_and_augment(file)
    img_array = np.expand_dims(img_array, axis=0)  # Membuat dimensi batch untuk prediksi

    # Prediksi gambar
    prediction = model.predict(img_array, verbose=0)

    # Menentukan kategori berdasarkan output model
    pred_class = np.argmax(prediction, axis=1)[0]
    label_map = {
        0: 'ABC Kopi Susu',
        1: 'BearBrand',
        2: 'Benecol rasa lyche botol 100ml',
        3: 'Cimory Susu Coklat Cashew',
        4: 'Cimory Yogurt Strawberry',
        5: 'Cimory bebas laktosa 250ml',
        6: 'Cola-Cola 390ml',
        7: 'Floridina',
        8: 'Fruit Tea Freeze 350ml',
        9: 'Hydro Coco Original 250ml',
        10: 'Ichitan Thai Green Tea',
        11: 'Larutan Penyegar rasa Jambu',
        12: 'Mizone 500ml',
        13: 'NU Green Tea Yogurt',
        14: 'Nutri boost Orange Flavour 250ml',
        15: 'Pocari Sweat',
        16: 'Sprite 390ml',
        17: 'Tebs Sparkling 330ml',
        18: 'Teh Kotak 200ml',
        19: 'Teh Pucuk Harum',
        20: 'Tehbotol sosro 250ml',
        21: 'Ultra milk coklat Ultrajaya 200ml',
        22: 'Ultramilk Fullcream 250ml',
        23: 'Yakult',
        24: 'You C 1000 orange',
        25: 'Pepsi Blue 330ml'

    }


    category = label_map[pred_class]

    with out:
        # Menampilkan gambar asli yang di-upload (tanpa augmentasi)
        plt.imshow(tf.keras.utils.array_to_img(original_img_array))
        plt.axis('off')
        plt.title(f"Uploaded Image (Original): {filename}")
        plt.show()

        # Menampilkan hasil prediksi kategori
        print(f"<b>Gambar '{filename}' termasuk dalam kategori:</b> <u>{category}</u>", end="\n\n")

        # Mencari data nutrisi dari file CSV berdasarkan kategori
        nutrition_info = df_nutrition[df_nutrition['Nama Produk'] == category]

        if not nutrition_info.empty:
            # Menampilkan data nutrisi sebagai tabel HTML
            print("Informasi Gizi:")
            display(HTML(nutrition_info.to_html(index=False)))
        else:
            print("<i>Data nutrisi tidak ditemukan untuk kategori ini.</i>", end="\n\n")

def on_upload_change(change):
    """ Fungsi untuk mengambil file dari widget dan menjalankan prediksi """
    # Mendapatkan file yang diupload
    for name, data in change.new.items():
        file_jpgdata = BytesIO(data['content'])  # Access content from the data dictionary
        file_predict(name, file_jpgdata, out)

# Mengamati perubahan pada widget upload
uploader.observe(on_upload_change, names='value')
# Out:
# FileUpload(value={}, accept='image/*', description='Upload', multiple=True)
# Output()
